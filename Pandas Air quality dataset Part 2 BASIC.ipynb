# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_quality = pd.read_csv(r"C:\Users\Hi\Dataset1\air_quality_no2.csv")

# %%
air_quality.head()
# Out:
#               datetime  station_antwerp  station_paris  station_london
# 0  2019-05-07 02:00:00              NaN            NaN            23.0
# 1  2019-05-07 03:00:00             50.5           25.0            19.0
# 2  2019-05-07 04:00:00             45.0           27.7            19.0
# 3  2019-05-07 05:00:00              NaN           50.4            16.0
# 4  2019-05-07 06:00:00              NaN           61.9             NaN

# %%
air_quality.plot()
# Out:
# <Axes: >

# %%
air_quality["station_paris"].plot()
# Out:
# <Axes: >

# %%
air_quality["station_london"].plot()
# Out:
# <Axes: >

# %%
air_quality.plot.scatter(x="station_london", y="station_paris", alpha=0.5)
# Out:
# <Axes: xlabel='station_london', ylabel='station_paris'>

# %%
air_quality.plot.scatter(x="station_london", y="station_antwerp", alpha=0.5)
# Out:
# <Axes: xlabel='station_london', ylabel='station_antwerp'>

# %%
air_quality.plot.box()
# Out:
# <Axes: >

# %%
axs = air_quality.plot.area(figsize=(12, 4), subplots=True)

# %%
air_quality["london_mg_per_cubic"] = air_quality["station_london"] * 1.882

# %%
air_quality.head()
# Out:
#               datetime  station_antwerp  station_paris  station_london  \
# 0  2019-05-07 02:00:00              NaN            NaN            23.0
# 1  2019-05-07 03:00:00             50.5           25.0            19.0
# 2  2019-05-07 04:00:00             45.0           27.7            19.0
# 3  2019-05-07 05:00:00              NaN           50.4            16.0
# 4  2019-05-07 06:00:00              NaN           61.9             NaN
#
#    london_mg_per_cubic
# 0               43.286
# 1               35.758
# 2               35.758
# 3               30.112
# 4                  NaN

# %%
air_quality["ratio_paris_antwerp"] = (air_quality["station_paris"] / air_quality["station_antwerp"] )

# %%
air_quality.head()
# Out:
#               datetime  station_antwerp  station_paris  station_london  \
# 0  2019-05-07 02:00:00              NaN            NaN            23.0
# 1  2019-05-07 03:00:00             50.5           25.0            19.0
# 2  2019-05-07 04:00:00             45.0           27.7            19.0
# 3  2019-05-07 05:00:00              NaN           50.4            16.0
# 4  2019-05-07 06:00:00              NaN           61.9             NaN
#
#    london_mg_per_cubic  ratio_paris_antwerp
# 0               43.286                  NaN
# 1               35.758             0.495050
# 2               35.758             0.615556
# 3               30.112                  NaN
# 4                  NaN                  NaN

# %%
air_quality_renamed = air_quality.rename( columns={"station_antwerp": "BETR801","station_paris": "FR04014",
                                                   "station_london": "London Westminster",})

# %%
air_quality.head()
# Out:
#               datetime  station_antwerp  station_paris  station_london  \
# 0  2019-05-07 02:00:00              NaN            NaN            23.0
# 1  2019-05-07 03:00:00             50.5           25.0            19.0
# 2  2019-05-07 04:00:00             45.0           27.7            19.0
# 3  2019-05-07 05:00:00              NaN           50.4            16.0
# 4  2019-05-07 06:00:00              NaN           61.9             NaN
#
#    london_mg_per_cubic  ratio_paris_antwerp
# 0               43.286                  NaN
# 1               35.758             0.495050
# 2               35.758             0.615556
# 3               30.112                  NaN
# 4                  NaN                  NaN

# %%
air_quality_renamed.head()
# Out:
#               datetime  BETR801  FR04014  London Westminster  \
# 0  2019-05-07 02:00:00      NaN      NaN                23.0
# 1  2019-05-07 03:00:00     50.5     25.0                19.0
# 2  2019-05-07 04:00:00     45.0     27.7                19.0
# 3  2019-05-07 05:00:00      NaN     50.4                16.0
# 4  2019-05-07 06:00:00      NaN     61.9                 NaN
#
#    london_mg_per_cubic  ratio_paris_antwerp
# 0               43.286                  NaN
# 1               35.758             0.495050
# 2               35.758             0.615556
# 3               30.112                  NaN
# 4                  NaN                  NaN

# %%
air_quality_renamed = air_quality_renamed.rename(columns=str.lower)

# %%
air_quality_renamed.head()
# Out:
#               datetime  betr801  fr04014  london westminster  \
# 0  2019-05-07 02:00:00      NaN      NaN                23.0
# 1  2019-05-07 03:00:00     50.5     25.0                19.0
# 2  2019-05-07 04:00:00     45.0     27.7                19.0
# 3  2019-05-07 05:00:00      NaN     50.4                16.0
# 4  2019-05-07 06:00:00      NaN     61.9                 NaN
#
#    london_mg_per_cubic  ratio_paris_antwerp
# 0               43.286                  NaN
# 1               35.758             0.495050
# 2               35.758             0.615556
# 3               30.112                  NaN
# 4                  NaN                  NaN
